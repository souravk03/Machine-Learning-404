# %% [markdown]
# <a href="https://colab.research.google.com/github/souravk03/Machine-Learning-404/blob/main/Fetching_data_from_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
url = "https://bhagavad-gita3.p.rapidapi.com/v2/chapters/"

querystring = {"skip":"0","limit":"18"}

headers = {
	"x-rapidapi-key": "650e38d5f8msh4e527fee9ffa54cp1ca7e6jsn549f9da92432",
	"x-rapidapi-host": "bhagavad-gita3.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

tempdf=pd.DataFrame(response.json())[['id','name','name_translated','verses_count','chapter_number','name_meaning']]

# %%
tempdf
# Out:
#     id                        name                 name_translated  \
# 0    1              अर्जुनविषादयोग              Arjuna Visada Yoga
# 1    2                   सांख्ययोग                    Sankhya Yoga
# 2    3                     कर्मयोग                      Karma Yoga
# 3    4         ज्ञानकर्मसंन्यासयोग        Jnana Karma Sanyasa Yoga
# 4    5              कर्मसंन्यासयोग              Karma Sanyasa Yoga
# 5    6                    ध्यानयोग                     Dhyana Yoga
# 6    7             ज्ञानविज्ञानयोग              Gyaan Vigyana Yoga
# 7    8              अक्षरब्रह्मयोग             Akshara Brahma Yoga
# 8    9        राजविद्याराजगुह्ययोग                 Raja Vidya Yoga
# 9   10                   विभूतियोग                   Vibhooti Yoga
# 10  11            विश्वरूपदर्शनयोग       Vishwaroopa Darshana Yoga
# 11  12                    भक्तियोग                     Bhakti Yoga
# 12  13  क्षेत्र-क्षेत्रज्ञविभागयोग  Ksetra Ksetrajna Vibhaaga Yoga
# ...

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
tempdf.to_csv('/content/drive/MyDrive/Colab Notebooks/BhagavadGita.csv')
