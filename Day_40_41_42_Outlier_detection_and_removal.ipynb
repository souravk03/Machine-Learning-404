# %% [markdown]
# <a href="https://colab.research.google.com/github/souravk03/Machine-Learning-404/blob/main/Day_40_41_42_Outlier_detection_and_removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # We use Z-Score to detect the outlier for normally distributed data
# Z_score  X'i=(Xi-Xmean)/std
#
# Anything is outlier whose z score is not between -3 to 3
#                     or
#
# we can also write in this format:
# **values should be  greater than mean-3*std and less than mean+3*std**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/placement (1).csv')
df.shape
# Out:
# (1000, 3)

# %%
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 28   7.23                  19.0       0
# 472  6.19                  38.0       1
# 919  6.59                  21.0       0
# 518  7.53                  22.0       0
# 451  5.94                  31.0       0

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])

plt.show()
# Out:
# /tmp/ipython-input-3792736820.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# /tmp/ipython-input-3792736820.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])

# %% [markdown]
# **As i have said before z score outlier detection works for normal distribution so we will use it for CGPA and not for Placement exam marks**

# %%
df['placement_exam_marks'].skew()
# Out:
# np.float64(0.8356419499466834)

# %% [markdown]
# right skewed

# %%
df['cgpa'].skew()
# Out:
# np.float64(-0.014529938929314918)

# %% [markdown]
# almost normal distrbution

# %%
print("Mean value of cgpa",df['cgpa'].mean())
print("Std value of cgpa",df['cgpa'].std())
print("Min value of cgpa",df['cgpa'].min())
print("Max value of cgpa",df['cgpa'].max())
# Out:
# Mean value of cgpa 6.96124
# Std value of cgpa 0.6158978751323894
# Min value of cgpa 4.89
# Max value of cgpa 9.12

# %%
# Finding the boundary values
print("Highest allowed",df['cgpa'].mean() + 3*df['cgpa'].std())
print("Lowest allowed",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# Highest allowed 8.808933625397168
# Lowest allowed 5.113546374602832

# %%
# Finding the outliers
df[(df['cgpa'] > 8.80) | (df['cgpa'] < 5.11)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %% [markdown]
# Trimming means removing the outlier from the data it is fast but for large outlier it makes the data thin

# %%
# Trimming

new_df = df[(df['cgpa'] < 8.80) & (df['cgpa'] > 5.11)]
new_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 991  7.04                  57.0       0
# 992  6.26                  12.0       0
# 993  6.73                  21.0       1
# 994  6.48                  63.0       0
# 998  8.62                  46.0       1
#
# [995 rows x 3 columns]

# %%
# Approach 2

# Calculating the Zscore

df['cgpa_zscore'] = (df['cgpa'] - df['cgpa'].mean())/df['cgpa'].std()

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed  cgpa_zscore
# 0  7.19                  26.0       1     0.371425
# 1  7.46                  38.0       1     0.809810
# 2  7.54                  40.0       1     0.939701
# 3  6.42                   8.0       1    -0.878782
# 4  7.23                  17.0       0     0.436371

# %%
df[df['cgpa_zscore'] > 3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 995  8.87                  44.0       1     3.099150
# 996  9.12                  65.0       1     3.505062

# %%
df[df['cgpa_zscore'] < -3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                  44.0       1    -3.314251
# 997  4.89                  34.0       0    -3.362960
# 999  4.90                  10.0       1    -3.346724

# %%
df[(df['cgpa_zscore'] > 3) | (df['cgpa_zscore'] < -3)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                  44.0       1    -3.314251
# 995  8.87                  44.0       1     3.099150
# 996  9.12                  65.0       1     3.505062
# 997  4.89                  34.0       0    -3.362960
# 999  4.90                  10.0       1    -3.346724

# %%
# Trimming
new_df = df[(df['cgpa_zscore'] < 3) & (df['cgpa_zscore'] > -3)]
new_df
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.19                  26.0       1     0.371425
# 1    7.46                  38.0       1     0.809810
# 2    7.54                  40.0       1     0.939701
# 3    6.42                   8.0       1    -0.878782
# 4    7.23                  17.0       0     0.436371
# ..    ...                   ...     ...          ...
# 991  7.04                  57.0       0     0.127878
# 992  6.26                  12.0       0    -1.138565
# 993  6.73                  21.0       1    -0.375452
# 994  6.48                  63.0       0    -0.781363
# 998  8.62                  46.0       1     2.693239
#
# [995 rows x 4 columns]

# %% [markdown]
# #Capping

# %%
upper_limit = df['cgpa'].mean() + 3*df['cgpa'].std()
lower_limit = df['cgpa'].mean() - 3*df['cgpa'].std()
lower_limit
# Out:
# np.float64(5.113546374602832)

# %%
df['cgpa'] = np.where(
    df['cgpa']>upper_limit,
    upper_limit,
    np.where(
        df['cgpa']<lower_limit,
        lower_limit,
        df['cgpa']
    )
)

# %%
df.shape
# Out:
# (1000, 4)

# %%
df['cgpa'].describe()
# Out:
# count    1000.000000
# mean        6.961499
# std         0.612688
# min         5.113546
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         8.808934
# Name: cgpa, dtype: float64

# %% [markdown]
# #day43-outlier-removal-using-iqr-method

# %% [markdown]
# #**For Skewed distribution of data**

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/placement (1).csv')
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])

plt.show()
# Out:
# /tmp/ipython-input-3792736820.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# /tmp/ipython-input-3792736820.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])

# %%
df['placement_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.boxplot(df['placement_exam_marks'])
# Out:
# <Axes: ylabel='placement_exam_marks'>

# %%
# Finding the IQR
percentile25 = df['placement_exam_marks'].quantile(0.25)
percentile75 = df['placement_exam_marks'].quantile(0.75)

# %%
percentile75
# Out:
# np.float64(44.0)

# %%
iqr=percentile75-percentile25

# %%
iqr
# Out:
# np.float64(27.0)

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
upper_limit
# Out:
# np.float64(84.5)

# %%
print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 84.5
# Lower limit -23.5

# %% [markdown]
# #finding outlier

# %%
df[df['placement_exam_marks'] > upper_limit]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                  94.0       1
# 40   6.60                  86.0       1
# 61   7.51                  86.0       0
# 134  6.33                  93.0       0
# 162  7.80                  90.0       0
# 283  7.09                  87.0       0
# 290  8.38                  87.0       0
# 311  6.97                  87.0       1
# 324  6.64                  90.0       0
# 630  6.56                  96.0       1
# 685  6.05                  87.0       1
# 730  6.14                  90.0       1
# 771  7.31                  86.0       1
# 846  6.99                  97.0       0
# 917  5.95                 100.0       0

# %%
df[df['placement_exam_marks'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [cgpa, placement_exam_marks, placed]
# Index: []

# %% [markdown]
# #Trimming

# %%
new_df = df[df['placement_exam_marks'] < upper_limit]
new_df.shape
# Out:
# (985, 3)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(new_df['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(new_df['placement_exam_marks'])

plt.show()
# Out:
# /tmp/ipython-input-3798459719.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# /tmp/ipython-input-3798459719.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['placement_exam_marks'])

# %% [markdown]
# #Capping

# %%
new_df_cap = df.copy()

new_df_cap['placement_exam_marks'] = np.where(
    new_df_cap['placement_exam_marks'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['placement_exam_marks'] < lower_limit,
        lower_limit,
        new_df_cap['placement_exam_marks']
    )
)

# %%
#np.where(condtion,true,false)
new_df_cap.shape
# Out:
# (1000, 3)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(new_df_cap['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(new_df_cap['placement_exam_marks'])

plt.show()
# Out:
# /tmp/ipython-input-3538926932.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# /tmp/ipython-input-3538926932.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df_cap['placement_exam_marks'])
