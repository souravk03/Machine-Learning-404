# %% [markdown]
# <a href="https://colab.research.google.com/github/souravk03/Machine-Learning-404/blob/main/Day_48_Simple_linear_Regression_using_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple Linear regression means there is only one input input feature or indpendent feature
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Regression is used to make prediction on linear data and if the almost linear then we can also use linear regression**
#
# ##**Used to predict continuous variable**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/placement (2).csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
from sklearn.model_selection import train_test_split

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m = lr.coef_
b = lr.intercept_

# %%
# y = mx + b

m * 8.58 + b
# Out:
# array([3.89111601])

# %%
m * 9.5 + b
# Out:
# array([4.40443183])

# %%
m * 100 + b
# Out:
# array([54.89908542])
