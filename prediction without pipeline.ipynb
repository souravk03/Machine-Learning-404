# %%
import pickle
import numpy as np
ohe_sex = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/Day 29/models/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/Day 29/models/ohe_embarked.pkl','rb'))
clf = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/Day 29/models/clf.pkl','rb'))

# %%
# Assume user input
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
test_input_sex
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([[0., 1.]])

# %%
test_input_embarked = ohe_embarked.transform(test_input[:,-1].reshape(1,1))
test_input_embarked
# Out:
# array([[0., 0., 1.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)
test_input_transformed.shape
# Out:
# (1, 10)

# %%
clf.predict(test_input_transformed)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3442723078.py in <cell line: 0>()
# ----> 1 clf.predict(test_input_transformed)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     528         """
#     529         check_is_fitted(self)
# --> 530         X = self._validate_X_predict(X, check_input)
#     531         proba = self.tree_.predict(X)
#     532         n_samples = X.shape[0]
#
# /usr/local/lib/python3.12/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     487             else:
#     488                 ensure_all_finite = True
# --> 489             X = validate_data(
#     490                 self,
#     491                 X,
#
# ...
