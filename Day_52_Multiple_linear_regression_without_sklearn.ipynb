# %% [markdown]
# <a href="https://colab.research.google.com/github/souravk03/Machine-Learning-404/blob/main/Day_52_Multiple_linear_regression_without_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Mathmetical Intuition**
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ##**Detour**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Retour
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Code from Scratch**
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from sklearn.datasets import load_diabetes

# %%
X,y=load_diabetes(return_X_y=True)

# %%
X.shape
# Out:
# (442, 10)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
# Out:
# (353, 10)

# %%
print(X_test.shape)
# Out:
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()

# %%
mlr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=mlr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
mlr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
mlr.intercept_
# Out:
# np.float64(151.88331005254167)

# %% [markdown]
# #**Creating my own linear regression class**
#
# ![image.png](data:image/png;base64,...)
#
#
# #**![image.png](data:image/png;base64,...)**

# %%
class myLR:

  def __init__(self):
    self.coef_=None
    self.intercept_=None

  def fit(self,X_train,y_train):
    X_train=np.insert(X_train,0,1,axis=1)

    # calcuate the coeffs
    betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
    self.intercept_ = betas[0]
    self.coef_ = betas[1:]

  def predict(self,X_test):
    y_pred = np.dot(X_test,self.coef_) + self.intercept_
    return y_pred

# %%
lr = myLR()
lr.fit(X_train,y_train)
X_train.shape
# Out:
# (353, 10)

# %%
y_pred = lr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.43993386615689634

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# np.float64(151.88331005254165)
